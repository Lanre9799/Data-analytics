# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r"C:\Users\admin\Desktop\Data analysis\online_retail.csv")
df.head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
# SHows the number of missing data in each column
df.isna().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.drop(columns=['index', 'InvoiceNo','StockCode'], inplace=True)
df
# Out:
#                                 Description  Quantity      InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 8:26
# 1                       WHITE METAL LANTERN         6   12/1/2010 8:26
# 2            CREAM CUPID HEARTS COAT HANGER         8   12/1/2010 8:26
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6   12/1/2010 8:26
# 4            RED WOOLLY HOTTIE WHITE HEART.         6   12/1/2010 8:26
# ...                                     ...       ...              ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  12/9/2011 12:50
# 541905         CHILDREN'S APRON DOLLY GIRL          6  12/9/2011 12:50
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  12/9/2011 12:50
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  12/9/2011 12:50
# 541908        BAKING SET 9 PIECE RETROSPOT          3  12/9/2011 12:50
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# ...

# %%
df.columns = df.columns.str.replace('Description', 'Products')
df
# Out:
#                                    Products  Quantity      InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 8:26
# 1                       WHITE METAL LANTERN         6   12/1/2010 8:26
# 2            CREAM CUPID HEARTS COAT HANGER         8   12/1/2010 8:26
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6   12/1/2010 8:26
# 4            RED WOOLLY HOTTIE WHITE HEART.         6   12/1/2010 8:26
# ...                                     ...       ...              ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  12/9/2011 12:50
# 541905         CHILDREN'S APRON DOLLY GIRL          6  12/9/2011 12:50
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  12/9/2011 12:50
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  12/9/2011 12:50
# 541908        BAKING SET 9 PIECE RETROSPOT          3  12/9/2011 12:50
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     541909 non-null  int64
#  2   InvoiceDate  541909 non-null  object
#  3   UnitPrice    541909 non-null  float64
#  4   CustomerID   406829 non-null  float64
#  5   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 24.8+ MB

# %%
df = df.astype({'CustomerID': str})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     541909 non-null  int64
#  2   InvoiceDate  541909 non-null  object
#  3   UnitPrice    541909 non-null  float64
#  4   CustomerID   541909 non-null  object
#  5   Country      541909 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 24.8+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df
# Out:
#                                    Products  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                     ...       ...                 ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12 2011-12-09 12:50:00
# 541905         CHILDREN'S APRON DOLLY GIRL          6 2011-12-09 12:50:00
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4 2011-12-09 12:50:00
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4 2011-12-09 12:50:00
# 541908        BAKING SET 9 PIECE RETROSPOT          3 2011-12-09 12:50:00
#
#         UnitPrice CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     541909 non-null  int64
#  2   InvoiceDate  541909 non-null  datetime64[ns]
#  3   UnitPrice    541909 non-null  float64
#  4   CustomerID   541909 non-null  object
#  5   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 24.8+ MB

# %%
pd.to_datetime(df['InvoiceDate'], format='%Y%m%d')
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
pd.to_datetime(df['InvoiceDate']).dt.date
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: InvoiceDate, Length: 541909, dtype: object

# %%
#Date format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']).dt.normalize()

# %%
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     541909 non-null  int64
#  2   InvoiceDate  541909 non-null  datetime64[ns]
#  3   UnitPrice    541909 non-null  float64
#  4   CustomerID   541909 non-null  object
#  5   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 24.8+ MB

# %%
df['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 00:00:00')

# %%
# np.NAN used to identify missing data
# np.NAN = 'nan'
filt = df['CustomerID'] == 'nan'
df[filt]
# Out:
#                                Products  Quantity InvoiceDate  UnitPrice  \
# 622                                 NaN        56  2010-12-01       0.00
# 1443    DECORATIVE ROSE BATHROOM BOTTLE         1  2010-12-01       2.51
# 1444    DECORATIVE CATS BATHROOM BOTTLE         2  2010-12-01       2.51
# 1445                 POLKADOT RAIN HAT          4  2010-12-01       0.85
# 1446              RAIN PONCHO RETROSPOT         2  2010-12-01       1.66
# ...                                 ...       ...         ...        ...
# 541536          JUMBO BAG RED RETROSPOT         5  2011-12-09       4.13
# 541537   JUMBO  BAG BAROQUE BLACK WHITE         4  2011-12-09       4.13
# 541538    LADIES & GENTLEMEN METAL SIGN         1  2011-12-09       4.96
# 541539                S/4 CACTI CANDLES         1  2011-12-09      10.79
# 541540                   DOTCOM POSTAGE         1  2011-12-09    1714.17
#
#        CustomerID         Country
# 622           nan  United Kingdom
# ...

# %%
df.tail(60)
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 541849        TABLECLOTH RED APPLES DESIGN          2  2011-12-09       9.95
# 541850                     WRAP RED APPLES         25  2011-12-09       0.42
# 541851        SET OF 3 CAKE TINS SKETCHBOOK         1  2011-12-09       1.95
# 541852                 CARD MOTORBIKE SANTA        24  2011-12-09       0.42
# 541853            SCANDINAVIAN REDS RIBBONS         2  2011-12-09       1.25
# 541854         6 RIBBONS ELEGANT CHRISTMAS          2  2011-12-09       0.39
# 541855             CINAMMON & ORANGE WREATH         1  2011-12-09       6.75
# 541856       PINK REGENCY TEACUP AND SAUCER         1  2011-12-09       2.95
# 541857              20 DOLLY PEGS RETROSPOT         1  2011-12-09       1.45
# 541858                        CHILLI LIGHTS         2  2011-12-09       5.75
# 541859          TEA TIME TEAPOT IN GIFT BOX         1  2011-12-09       4.95
# ...

# %%
df.isna().sum()
# Out:
# Products       1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     541909 non-null  int64
#  2   InvoiceDate  541909 non-null  datetime64[ns]
#  3   UnitPrice    541909 non-null  float64
#  4   CustomerID   541909 non-null  object
#  5   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 24.8+ MB

# %%
# drop missing products data using dropna
df.dropna(subset='Products', inplace=True)

# %%
df.isna().sum()
# Out:
# Products       0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 540455 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     540455 non-null  object
#  1   Quantity     540455 non-null  int64
#  2   InvoiceDate  540455 non-null  datetime64[ns]
#  3   UnitPrice    540455 non-null  float64
#  4   CustomerID   540455 non-null  object
#  5   Country      540455 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 28.9+ MB

# %%
filt = df['CustomerID'] == 'nan'
df[filt]
# Out:
#                                Products  Quantity InvoiceDate  UnitPrice  \
# 1443    DECORATIVE ROSE BATHROOM BOTTLE         1  2010-12-01       2.51
# 1444    DECORATIVE CATS BATHROOM BOTTLE         2  2010-12-01       2.51
# 1445                 POLKADOT RAIN HAT          4  2010-12-01       0.85
# 1446              RAIN PONCHO RETROSPOT         2  2010-12-01       1.66
# 1447                 VINTAGE SNAP CARDS         9  2010-12-01       1.66
# ...                                 ...       ...         ...        ...
# 541536          JUMBO BAG RED RETROSPOT         5  2011-12-09       4.13
# 541537   JUMBO  BAG BAROQUE BLACK WHITE         4  2011-12-09       4.13
# 541538    LADIES & GENTLEMEN METAL SIGN         1  2011-12-09       4.96
# 541539                S/4 CACTI CANDLES         1  2011-12-09      10.79
# 541540                   DOTCOM POSTAGE         1  2011-12-09    1714.17
#
#        CustomerID         Country
# 1443          nan  United Kingdom
# ...

# %%
def update_customerid(custid):
    if custid == 'nan':
        return 'C99999'
    else:
        return custid
df['CustomerID'] = df['CustomerID'].map(update_customerid)
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
# handle missing data for the CustomerID
filt = df['CustomerID'] == 'nan'
df[filt]
# Out:
# Empty DataFrame
# Columns: [Products, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# check and remove duplicate records
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 521840 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     521840 non-null  object
#  1   Quantity     521840 non-null  int64
#  2   InvoiceDate  521840 non-null  datetime64[ns]
#  3   UnitPrice    521840 non-null  float64
#  4   CustomerID   521840 non-null  object
#  5   Country      521840 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 27.9+ MB

# %%
# check the data formats.
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
filt = (df['Quantity'] < 1)
df[filt]
# Out:
#                                 Products  Quantity InvoiceDate  UnitPrice  \
# 141                             Discount        -1  2010-12-01      27.50
# 154      SET OF 3 COLOURED  FLYING DUCKS        -1  2010-12-01       4.65
# 235       PLASTERS IN TIN CIRCUS PARADE        -12  2010-12-01       1.65
# 236     PACK OF 12 PINK PAISLEY TISSUES        -24  2010-12-01       0.29
# 237     PACK OF 12 BLUE PAISLEY TISSUES        -24  2010-12-01       0.29
# ...                                  ...       ...         ...        ...
# 540449   ZINC T-LIGHT HOLDER STARS SMALL       -11  2011-12-09       0.83
# 541541                            Manual        -1  2011-12-09     224.69
# 541715        VICTORIAN SEWING BOX LARGE        -5  2011-12-09      10.95
# 541716  HANGING HEART JAR T-LIGHT HOLDER        -1  2011-12-09       1.25
# 541717     36 PENCILS TUBE RED RETROSPOT        -5  2011-12-09       1.25
#
#        CustomerID         Country
# 141       14527.0  United Kingdom
# ...

# %%
# remove the row with values less than 1
df = df.drop(df[filt].index)

# %%
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
filt = (df['Quantity'] < 1)
df[filt]
# Out:
# Empty DataFrame
# Columns: [Products, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# check for prices that are 0 or below 0
filt = df['UnitPrice'] <= 0
df[filt]
# Out:
#                                 Products  Quantity InvoiceDate  UnitPrice  \
# 6391                              amazon        20  2010-12-03        0.0
# 6392                              amazon        15  2010-12-03        0.0
# 9302        ROUND CAKE TIN VINTAGE GREEN         1  2010-12-05        0.0
# 14335       CREAM SWEETHEART LETTER RACK         1  2010-12-07        0.0
# 14336   ZINC WILLIE WINKIE  CANDLE STICK         1  2010-12-07        0.0
# ...                                  ...       ...         ...        ...
# 524622                            Amazon         1  2011-12-05        0.0
# 535325                             check        41  2011-12-07        0.0
# 535334                             check        14  2011-12-07        0.0
# 538504      POLYESTER FILLER PAD 45x45cm       240  2011-12-08        0.0
# 538505      POLYESTER FILLER PAD 40x40cm       300  2011-12-08        0.0
#
#        CustomerID         Country
# 6391       C99999  United Kingdom
# ...

# %%
# remove rows with unit price below or equals 0
# remove all rows with quantity less then 0
df = df.drop(df[filt].index)
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
filt = df['CustomerID'] == 'C99999'
df[~filt] # ~means not
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
df[~filt].loc[:,'CustomerID']
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 391255, dtype: object

# %%
df[~filt].loc[:,'CustomerID'].str[:5]
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: CustomerID, Length: 391255, dtype: object

# %%
filt[:5]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: CustomerID, dtype: bool

# %%
def slicing_string(custid):
    
    if custid == 'C99999':
        return 'C99999'
    else:
       
        return custid[:5] 

df['CustomerID'] = df['CustomerID'].map(slicing_string)
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
filt = df['CustomerID'] == 'C99999'
df[filt]
# Out:
#                                Products  Quantity InvoiceDate  UnitPrice  \
# 1443    DECORATIVE ROSE BATHROOM BOTTLE         1  2010-12-01       2.51
# 1444    DECORATIVE CATS BATHROOM BOTTLE         2  2010-12-01       2.51
# 1445                 POLKADOT RAIN HAT          4  2010-12-01       0.85
# 1446              RAIN PONCHO RETROSPOT         2  2010-12-01       1.66
# 1447                 VINTAGE SNAP CARDS         9  2010-12-01       1.66
# ...                                 ...       ...         ...        ...
# 541536          JUMBO BAG RED RETROSPOT         5  2011-12-09       4.13
# 541537   JUMBO  BAG BAROQUE BLACK WHITE         4  2011-12-09       4.13
# 541538    LADIES & GENTLEMEN METAL SIGN         1  2011-12-09       4.96
# 541539                S/4 CACTI CANDLES         1  2011-12-09      10.79
# 541540                   DOTCOM POSTAGE         1  2011-12-09    1714.17
#
#        CustomerID         Country
# 1443       C99999  United Kingdom
# ...

# %%
df[~filt]
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          466883
# Germany                   9013
# France                    8363
# EIRE                      7806
# Spain                     2479
# Netherlands               2354
# Belgium                   2031
# Switzerland               1958
# Portugal                  1476
# Australia                 1174
# Norway                    1070
# Italy                      758
# Channel Islands            746
# Finland                    685
# Cyprus                     602
# Sweden                     450
# Unspecified                428
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     291
# Hong Kong                  280
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %%
df['Products'].value_counts()
# Out:
# Products
# WHITE HANGING HEART T-LIGHT HOLDER    2271
# JUMBO BAG RED RETROSPOT               2010
# REGENCY CAKESTAND 3 TIER              1977
# PARTY BUNTING                         1663
# LUNCH BAG RED RETROSPOT               1552
#                                       ...
# ETCHED GLASS STAR TREE DECORATION        1
# PINK BOUDOIR T-LIGHT HOLDER              1
# OCEAN STRIPE HAMMOCK                     1
# INCENSE BAZAAR PEACH                     1
# PAPER CRAFT , LITTLE BIRDIE              1
# Name: count, Length: 4026, dtype: int64

# %%
filt = df['Country']== 'Unspecified'
# df[filt]
# remove rows with Country = unspecified.
df.drop(df[filt].index, inplace = True)
df
# Out:
#                                    Products  Quantity InvoiceDate  UnitPrice  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01       2.55
# 1                       WHITE METAL LANTERN         6  2010-12-01       3.39
# 2            CREAM CUPID HEARTS COAT HANGER         8  2010-12-01       2.75
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01       3.39
# 4            RED WOOLLY HOTTIE WHITE HEART.         6  2010-12-01       3.39
# ...                                     ...       ...         ...        ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  2011-12-09       0.85
# 541905         CHILDREN'S APRON DOLLY GIRL          6  2011-12-09       2.10
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  2011-12-09       4.15
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  2011-12-09       4.15
# 541908        BAKING SET 9 PIECE RETROSPOT          3  2011-12-09       4.95
#
#        CustomerID         Country
# ...

# %%
filt = df['Country']== 'Unspecified'
df[filt]
# Out:
# Empty DataFrame
# Columns: [Products, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511187 entries, 0 to 541908
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Products     511187 non-null  object
#  1   Quantity     511187 non-null  int64
#  2   InvoiceDate  511187 non-null  datetime64[ns]
#  3   UnitPrice    511187 non-null  float64
#  4   CustomerID   511187 non-null  object
#  5   Country      511187 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 27.3+ MB

# %%
df.to_csv(r"C:\Users\admin\Desktop\Data analysis\online_retail_CLEANED.csv", index=False) # index =False, when exported to CSV it tries to index again
