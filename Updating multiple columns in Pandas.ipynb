# %%
# pandas for data analysis.
# data structures in Pandas 
# Pandas - Panel Data
# It has 2 data structures - Series and the DataFrame

import pandas as pd
results = {
    'names' : ['Tola', 'Tosin', 'Tobi', 'Titi', 'Tayo', 'Tolu', 'Tom'],
    'scores': [40, 60, 70, 54, 90, 63, 82],
    'grades': ['E', 'B', 'A', 'C', 'A', 'B', 'A'],
    'gender': ['M', 'F', 'M', 'F', 'F', 'F', 'M'],
    'emails': ['tola@gmail.com', 'tosin@gmail.com', 'tobi@gmail.com', 'titi@gmail.com', 'tayo@gmail.com', 'tolu@gmail.com', 'tom@gmail.com']
}

df = pd.DataFrame(results)
df
# Out:
#    names  scores grades gender           emails
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   7 non-null      object
#  1   scores  7 non-null      int64
#  2   grades  7 non-null      object
#  3   gender  7 non-null      object
#  4   emails  7 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 412.0+ bytes

# %%
df['emails'].str.contains('N')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: emails, dtype: bool

# %%
df['emails'].str.contains('n')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: emails, dtype: bool

# %%
filt = df['emails'].str.contains('n')
df[filt]
# Out:
#    names  scores grades gender           emails
# 1  Tosin      60      B      F  tosin@gmail.com

# %%
# updating columns and rows
# columns
df
# Out:
#    names  scores grades gender           emails
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com

# %%
# change the emails column to email_address
# 1. use the str.replace() method
df.columns.str.replace('emails', 'email_address')
# Out:
# Index(['names', 'scores', 'grades', 'gender', 'email_address'], dtype='object')

# %%
df
# Out:
#    names  scores grades gender           emails
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com

# %%
df.columns.str.replace('emails', 'email_address', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.columns.str.replace('emails', 'email_address', inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.replace() got an unexpected keyword argument 'inplace'

# %%
# rename or update a single column name.
df.columns = df.columns.str.replace('emails', 'email_address')
df
# Out:
#    names  scores grades gender    email_address
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com

# %%
# rename multiple columns
df.rename(columns = {'scores':'student_scores', 'email_address':'emails'}, inplace=True)
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              40      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
# effect a general change to all column names
# e.g. convert all column names to upper case letters
df.columns = [ col.upper() for col in df.columns ] # using a list comprehension.
df
# Out:
#    NAMES  STUDENT_SCORES GRADES GENDER           EMAILS
# 0   Tola              40      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
df.columns = [ col.lower() for col in df.columns ] # using a list comprehension.
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              40      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
# updating rows.
# updating a single row. All values in the row must be updated.
df.loc[2] = ['Teresa', 72, 'A', 'F', 'teresa@gmail.com']
df
# Out:
#     names  student_scores grades gender            emails
# 0    Tola              40      E      M    tola@gmail.com
# 1   Tosin              60      B      F   tosin@gmail.com
# 2  Teresa              72      A      F  teresa@gmail.com
# 3    Titi              54      C      F    titi@gmail.com
# 4    Tayo              90      A      F    tayo@gmail.com
# 5    Tolu              63      B      F    tolu@gmail.com
# 6     Tom              82      A      M     tom@gmail.com

# %%
# update values in selected columns
df.loc[2, ['names', 'student_scores', 'gender']] = ['Tobi', 70, 'M']
df
# Out:
#    names  student_scores grades gender            emails
# 0   Tola              40      E      M    tola@gmail.com
# 1  Tosin              60      B      F   tosin@gmail.com
# 2   Tobi              70      A      M  teresa@gmail.com
# 3   Titi              54      C      F    titi@gmail.com
# 4   Tayo              90      A      F    tayo@gmail.com
# 5   Tolu              63      B      F    tolu@gmail.com
# 6    Tom              82      A      M     tom@gmail.com

# %%
# updating a single value
df.loc[2, 'emails'] = 'tobi@gmail.com'
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              40      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
# updating multiple rows in a column.
# this can be done using functions such as
# apply, map. Others are applymap and replace.

# apply function updates all the row values in a column
# map function updates selected values.

# apply works with both series and dataframes.
# we mostly use it with series.

# let's say we want to add 1 to every student's score.

def update_score(score):
    return score + 1

df['student_scores'] = df['student_scores'].apply(update_score)
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              41      E      M   tola@gmail.com
# 1  Tosin              61      B      F  tosin@gmail.com
# 2   Tobi              71      A      M   tobi@gmail.com
# 3   Titi              55      C      F   titi@gmail.com
# 4   Tayo              91      A      F   tayo@gmail.com
# 5   Tolu              64      B      F   tolu@gmail.com
# 6    Tom              83      A      M    tom@gmail.com

# %%
# rewrite the above using a lambda expression
# the lambda function will deduct 1 from all the scores

df['student_scores'] = df['student_scores'].apply(lambda score: score - 1)
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              40      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
# map method only works with series data
# let's say we only want to add 5 to students that scored below 50
# and also adjust their grade to "C"

def update_student_score(score):
    if score < 50:
        return score + 5
    else:
        return score

df['student_scores'] = df['student_scores'].map(update_student_score)
df
# Out:
#    names  student_scores grades gender           emails
# 0   Tola              45      E      M   tola@gmail.com
# 1  Tosin              60      B      F  tosin@gmail.com
# 2   Tobi              70      A      M   tobi@gmail.com
# 3   Titi              54      C      F   titi@gmail.com
# 4   Tayo              90      A      F   tayo@gmail.com
# 5   Tolu              63      B      F   tolu@gmail.com
# 6    Tom              82      A      M    tom@gmail.com

# %%
# update the grades column as follows.
# if score is above 70, grade is 'A'
# score 60 - 69, grade is 'B'
# score 50 - 59, grade is 'C'
# score 45 - 49, grade is 'D'
# score 40 - 44, grade is 'E'
# score below 40, grade is 'F'

df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
for d in df.index:
    print(d)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# consider the codes for updating 1 or more columns of a row of data.
df
# Out:
#    names  scores grades gender           emails
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com

# %%
for i in df.index:
    if df.loc[i, 'scores'] >= 70:
        df.loc[i, 'grades'] = 'A'
    elif df.loc[i, 'scores'] >= 60 and df.loc[i, 'scores'] <= 69:
        df.loc[i, 'grades'] = 'B'
    elif df.loc[i, 'scores'] >= 50 and df.loc[i, 'scores'] <= 59:
        df.loc[i, 'grades'] = 'C'
    elif df.loc[i, 'scores'] >= 45 and df.loc[i, 'scores'] <= 49:
        df.loc[i, 'grades'] = 'D'        
    elif df.loc[i, 'scores'] >= 40 and df.loc[i, 'scores'] <= 44:
        df.loc[i, 'grades'] = 'E'
    elif df.loc[i, 'scores'] < 40:
        df.loc[i, 'grades'] = 'F'   

df
# Out:
#    names  scores grades gender           emails
# 0   Tola      40      E      M   tola@gmail.com
# 1  Tosin      60      B      F  tosin@gmail.com
# 2   Tobi      70      A      M   tobi@gmail.com
# 3   Titi      54      C      F   titi@gmail.com
# 4   Tayo      90      A      F   tayo@gmail.com
# 5   Tolu      63      B      F   tolu@gmail.com
# 6    Tom      82      A      M    tom@gmail.com
