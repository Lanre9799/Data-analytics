# %%
import numpy as np
import pandas as pd
import matplotlib as plt 

yo15_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2015CLEANED.csv")
yo16_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2016CLEANED.csv")
yo17_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2017CLEANED.csv")
yo18_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2018CLEANED.csv")
yo19_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2019CLEANED.csv")

# %%
 yo15_df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  \
# 0             1.397           1.350            0.941    0.666
# ...
