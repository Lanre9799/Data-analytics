# %%
import numpy as np
import pandas as pd
import matplotlib as plt 

yo15_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2015.csv")
yo15_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
yo16_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2016.csv")
yo16_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
yo17_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2017.csv")
yo17_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
yo18_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2018.csv")
yo18_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
yo19_df = pd.read_csv(r"C:\Users\admin\Desktop\happiness_datasets\2019.csv")
yo19_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
yo15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
yo15_df.drop(columns=['Standard Error', 'Dystopia Residual'], inplace=True)
yo15_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
yo15_df.rename(columns = {'Economy (GDP per Capita)':'GDP per Capita', 'Health (Life Expectancy)':'Life Expectancy', 'Trust (Government Corruption)':'Government Corruption', 'Family':'Social support'}, inplace=True)
yo15_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.587         1.39651         1.34951          0.94143
# ...

# %%
yo15_df = yo15_df.round({'GDP per Capita': 3, 'Social support': 3, 'Life Expectancy': 3, 'Freedom': 3,'Government Corruption': 3,'Generosity': 3})

# %%
yo15_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.587           1.397           1.350            0.941
# ...

# %%
yo15_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2015CLEANED.csv", index=False)

# %%
yo16_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
yo16_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
yo16_df.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval','Dystopia Residual' ], inplace=True)
yo16_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# ...

# %%
yo16_df.rename(columns = {'Economy (GDP per Capita)':'GDP per Capita', 'Health (Life Expectancy)':'Life Expectancy', 'Trust (Government Corruption)':'Government Corruption', 'Family':'Social support'}, inplace=True)
yo16_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.526         1.44178         1.16374          0.79504
# ...

# %%
yo16_df = yo16_df.round({'GDP per Capita': 3, 'Social support': 3, 'Life Expectancy': 3, 'Freedom': 3,'Government Corruption': 3,'Generosity': 3})
yo16_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.526           1.442           1.164            0.795
# ...

# %%
yo16_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2016CLEANED.csv", index=False)

# %%
yo17_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
yo17_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
yo17_df.drop(columns=['Whisker.high', 'Whisker.low','Dystopia.Residual' ], inplace=True)
yo17_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
yo17_df.rename(columns = {'Happiness.Rank':'Happiness Rank', 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.':'GDP per Capita', 'Family':'Social support', 'Health..Life.Expectancy.':'Life Expectancy', 'Trust..Government.Corruption.':'Government Corruption' }, inplace=True)
yo17_df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP per Capita  Social support  Life Expectancy   Freedom  Generosity  \
# 0          1.616463        1.533524         0.796667  0.635423    0.362012
# ...

# %%
yo17_df = yo17_df.round({'GDP per Capita': 3, 'Social support': 3, 'Life Expectancy': 3, 'Freedom': 3,'Government Corruption': 3,'Generosity': 3})
yo17_df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.616           1.534            0.797    0.635       0.362
# ...

# %%
yo17_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2017CLEANED.csv", index=False)

# %%
yo18_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
yo18_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
yo18_df.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'Healthy life expectancy':'Life Expectancy', 'Freedom to make life choices':'Freedom','Perceptions of corruption':'Government Corruption' }, inplace=True)
yo18_df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      GDP per capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.305           1.592            0.874    0.681       0.202
# ...

# %%
yo18_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2018CLEANED.csv", index=False)

# %%
yo19_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
yo19_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
yo19_df.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'Healthy life expectancy':'Life Expectancy', 'Freedom to make life choices':'Freedom','Perceptions of corruption':'Government Corruption' }, inplace=True)
yo19_df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.340           1.587            0.986    0.596       0.153
# ...

# %%
yo19_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2019CLEANED.csv", index=False)

# %%
yo15_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.587           1.397           1.350            0.941
# ...

# %%
yo15_df.drop(columns=['Happiness Rank'], inplace=True)
yo15_df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  \
# 0             1.397           1.350            0.941    0.666
# ...

# %%
yo15_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2015CLEANED.csv", index=False)

# %%
yo16_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  GDP per Capita  Social support  Life Expectancy  \
# 0              7.526           1.442           1.164            0.795
# ...

# %%
yo16_df.drop(columns=['Happiness Rank'], inplace=True)
yo16_df
# Out:
#          Country                           Region  Happiness Score  \
# 0        Denmark                   Western Europe            7.526
# 1    Switzerland                   Western Europe            7.509
# 2        Iceland                   Western Europe            7.501
# 3         Norway                   Western Europe            7.498
# 4        Finland                   Western Europe            7.413
# ..           ...                              ...              ...
# 152        Benin               Sub-Saharan Africa            3.484
# 153  Afghanistan                    Southern Asia            3.360
# 154         Togo               Sub-Saharan Africa            3.303
# 155        Syria  Middle East and Northern Africa            3.069
# 156      Burundi               Sub-Saharan Africa            2.905
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  \
# 0             1.442           1.164            0.795    0.579
# ...

# %%
yo16_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2016CLEANED.csv", index=False)

# %%
yo17_df
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.616           1.534            0.797    0.635       0.362
# ...

# %%
yo17_df.drop(columns=['Happiness Rank'], inplace=True)
yo17_df
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                      Norway            7.537           1.616
# 1                     Denmark            7.522           1.482
# 2                     Iceland            7.504           1.481
# 3                 Switzerland            7.494           1.565
# 4                     Finland            7.469           1.444
# ..                        ...              ...             ...
# 150                    Rwanda            3.471           0.369
# 151                     Syria            3.462           0.777
# 152                  Tanzania            3.349           0.511
# 153                   Burundi            2.905           0.092
# 154  Central African Republic            2.693           0.000
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.534            0.797    0.635       0.362
# 1             1.551            0.793    0.626       0.355
# ...

# %%
yo17_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2017CLEANED.csv", index=False)

# %%
yo18_df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      GDP per capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.305           1.592            0.874    0.681       0.202
# ...

# %%
yo18_df.drop(columns=['Happiness Rank'], inplace=True)
yo18_df
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.632           1.305
# 1                      Norway            7.594           1.456
# 2                     Denmark            7.555           1.351
# 3                     Iceland            7.495           1.343
# 4                 Switzerland            7.487           1.420
# ..                        ...              ...             ...
# 151                     Yemen            3.355           0.442
# 152                  Tanzania            3.303           0.455
# 153               South Sudan            3.254           0.337
# 154  Central African Republic            3.083           0.024
# 155                   Burundi            2.905           0.091
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.592            0.874    0.681       0.202
# 1             1.582            0.861    0.686       0.286
# ...

# %%
yo18_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2018CLEANED.csv", index=False)

# %%
yo19_df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per capita  Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.340           1.587            0.986    0.596       0.153
# ...

# %%
yo19_df.drop(columns=['Happiness Rank'], inplace=True)
yo19_df
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.769           1.340
# 1                     Denmark            7.600           1.383
# 2                      Norway            7.554           1.488
# 3                     Iceland            7.494           1.380
# 4                 Netherlands            7.488           1.396
# ..                        ...              ...             ...
# 151                    Rwanda            3.334           0.359
# 152                  Tanzania            3.231           0.476
# 153               Afghanistan            3.203           0.350
# 154  Central African Republic            3.083           0.026
# 155               South Sudan            2.853           0.306
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.587            0.986    0.596       0.153
# 1             1.573            0.996    0.592       0.252
# ...

# %%
yo19_df.to_csv(r"C:\Users\admin\Desktop\happiness_datasets\2019CLEANED.csv", index=False)

# %%
yo15_df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  \
# 0             1.397           1.350            0.941    0.666
# ...

# %%
yo16_df
# Out:
#          Country                           Region  Happiness Score  \
# 0        Denmark                   Western Europe            7.526
# 1    Switzerland                   Western Europe            7.509
# 2        Iceland                   Western Europe            7.501
# 3         Norway                   Western Europe            7.498
# 4        Finland                   Western Europe            7.413
# ..           ...                              ...              ...
# 152        Benin               Sub-Saharan Africa            3.484
# 153  Afghanistan                    Southern Asia            3.360
# 154         Togo               Sub-Saharan Africa            3.303
# 155        Syria  Middle East and Northern Africa            3.069
# 156      Burundi               Sub-Saharan Africa            2.905
#
#      GDP per Capita  Social support  Life Expectancy  Freedom  \
# 0             1.442           1.164            0.795    0.579
# ...

# %%
yo17_df
# Out:
#                       Country  Happiness Score  GDP per Capita  \
# 0                      Norway            7.537           1.616
# 1                     Denmark            7.522           1.482
# 2                     Iceland            7.504           1.481
# 3                 Switzerland            7.494           1.565
# 4                     Finland            7.469           1.444
# ..                        ...              ...             ...
# 150                    Rwanda            3.471           0.369
# 151                     Syria            3.462           0.777
# 152                  Tanzania            3.349           0.511
# 153                   Burundi            2.905           0.092
# 154  Central African Republic            2.693           0.000
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.534            0.797    0.635       0.362
# 1             1.551            0.793    0.626       0.355
# ...

# %%
yo18_df
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.632           1.305
# 1                      Norway            7.594           1.456
# 2                     Denmark            7.555           1.351
# 3                     Iceland            7.495           1.343
# 4                 Switzerland            7.487           1.420
# ..                        ...              ...             ...
# 151                     Yemen            3.355           0.442
# 152                  Tanzania            3.303           0.455
# 153               South Sudan            3.254           0.337
# 154  Central African Republic            3.083           0.024
# 155                   Burundi            2.905           0.091
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.592            0.874    0.681       0.202
# 1             1.582            0.861    0.686       0.286
# ...

# %%
yo19_df
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.769           1.340
# 1                     Denmark            7.600           1.383
# 2                      Norway            7.554           1.488
# 3                     Iceland            7.494           1.380
# 4                 Netherlands            7.488           1.396
# ..                        ...              ...             ...
# 151                    Rwanda            3.334           0.359
# 152                  Tanzania            3.231           0.476
# 153               Afghanistan            3.203           0.350
# 154  Central African Republic            3.083           0.026
# 155               South Sudan            2.853           0.306
#
#      Social support  Life Expectancy  Freedom  Generosity  \
# 0             1.587            0.986    0.596       0.153
# 1             1.573            0.996    0.592       0.252
# ...

# %%
yo19_df['Happiness Score'].max()
# Out:
# 7.769
